# %% [markdown]
# #A primeira aula de Análise Vetorial
#
# **negrito**
#
# normal

# %% [markdown]
# ##Introdução

# %% [markdown]
# Anaconda Powershell Terminal
#
# jupyter notebook

# %%
x = 2

# %%
print(x)
# Out:
# 2

# %%
x
# Out:
# 2

# %%
x = 2
print(x)
x
# Out:
# 2
# 2

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9063a9f0e032> in <module>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
1+1
# Out:
# 2

# %%
3*4
# Out:
# 12

# %%
3/4
# Out:
# 0.75

# %% [markdown]
# Para receber só o valor inteiro é só colocar 2 barras

# %%
3//4
# Out:
# 0

# %%
5//4
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
(2+3)*(5+6)
# Out:
# 55

# %%
2+3*5+6
# Out:
# 23

# %% [markdown]
# Entre operadores matemáticos e números é indicado usar espaço

# %% [markdown]
# Operador para pegar o restante

# %%
5%4
# Out:
# 1

# %% [markdown]
# @x e 1x n podem ser usadas como nome de variáveis, nomes de variáveis começam com letras

# %%
meu_primeira_aula = 10 #o que vier dps da hastag é aceita como comentário
#segunda variável
segunda_variavel = -2

# %%
1 + meu_primeira_aula
# Out:
# 11

# %%
a = 1 
b = 2

# %%
z = a + b

# %%
z
# Out:
# 3

# %%
a = 5

# %%
z
# Out:
# 3

# %%
z = a + b

# %%
z
# Out:
# 7

# %% [markdown]
# ##Strings
#
# ```
# # Isto está formatado como código
# ```

# %%
c = " Oi, tudo bem? "
d = ' Sim, estou. '

# %%
c
# Out:
# ' Oi, tudo bem? '

# %%
d
# Out:
# ' Sim, estou. '

# %%
c + d
# Out:
# ' Oi, tudo bem?  Sim, estou. '

# %%
3 * c
# Out:
# ' Oi, tudo bem?  Oi, tudo bem?  Oi, tudo bem? '

# %%
e = "It's name is Roxanne"

# %% [markdown]
# Usando aspas duplas n da peoblema com aspas simples

# %% [markdown]
# ##Boleanos

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False or True
# Out:
# True

# %% [markdown]
# ##Lists

# %%
#nao usar "list" como nome de lista, sempre usar outro nome
My_list = [1,2,3]
My_list
# Out:
# [1, 2, 3]

# %%
My_list2 = ["hi",1,2,3]
My_list3 = [1,2,3,[4,5,6,[7,8,9]]]
My_list4 = [a,b,z]

# %%
My_list4
# Out:
# [5, 2, 7]

# %%
My_list + My_list4
# Out:
# [1, 2, 3, 5, 2, 7]
