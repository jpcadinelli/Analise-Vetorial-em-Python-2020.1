# %%
import av_utils as av

# %% [markdown]
# **Aula 13:** gravação ensinando a colocar um arquivo para ser importado no notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Uma parte da matéria perdida

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Capítulo 13 terminado!
